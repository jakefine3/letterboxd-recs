# %%
# use to experiment w/ code / explore created models

# %%
import pandas as pd
import sys
sys.path.insert(0, '..')

from src.ingestion.csv_loader import load_ratings

# %%
df = load_ratings('../data/raw/letterboxd-jakefine-2026-05-18-13-16-utc/ratings.csv')
df
# Out:
#                                   name  year  rating        letterboxd_uri
# 0                             Parasite  2019     4.5  https://boxd.it/hTha
# 1    Everything Everywhere All at Once  2022     3.0  https://boxd.it/jUk4
# 2                           Fight Club  1999     4.0  https://boxd.it/2a9q
# 3                         Interstellar  2014     4.5  https://boxd.it/4VZ8
# 4                                Joker  2019     3.5  https://boxd.it/h4cS
# ..                                 ...   ...     ...                   ...
# 314                 Return of the Jedi  1983     4.0  https://boxd.it/27Vm
# 315                          The Drama  2026     2.5  https://boxd.it/OA2w
# 316                     The Mastermind  2025     2.0  https://boxd.it/Q7ge
# 317              How to Make a Killing  2026     2.5  https://boxd.it/gLi8
# 318                      The Godfather  1972     4.0  https://boxd.it/2aNK
#
# [319 rows x 4 columns]
